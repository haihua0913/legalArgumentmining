# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.21.1-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 14.7 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 13.1 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 70.8 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.8.1 tokenizers-0.12.1 transformers-4.21.1

# %%
import pandas as pd, glob, re, string,seaborn as sns, random, numpy as np, os, transformers, torch, matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, LabelBinarizer
from sklearn.metrics import accuracy_score,confusion_matrix,precision_recall_fscore_support,roc_auc_score, classification_report, auc, roc_curve,f1_score
from tqdm import tqdm
# specify GPU
device = torch.device("cuda")
from transformers.file_utils import is_tf_available, is_torch_available, is_torch_tpu_available
from transformers import BertTokenizerFast, BertForSequenceClassification ,BertTokenizer, AutoModel, AutoTokenizer,Trainer, TrainingArguments,AutoModelForPreTraining,AutoModelForSequenceClassification

# %%
def create_dataframe(path):
    train_files = glob.glob(path + "/*.csv")
    df = pd.concat([pd.read_csv(filename, index_col=None, header=0) for filename in train_files], axis=0, ignore_index=True)
    df = df.drop(['Unnamed: 0'],axis=1)
    return df
def set_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    if is_torch_available():
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        # safe to call this function even if cuda is not available
    if is_tf_available():
        import tensorflow as tf
        tf.random.set_seed(seed)
class LegalDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels
    def __getitem__(self, idx):
        item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
        item["labels"] = torch.tensor([self.labels[idx]])
        return item
    def __len__(self):
        return len(self.labels)
def get_prediction(text):
    inputs = tokenizer(text, padding=True, truncation=True, max_length=max_length, return_tensors="pt").to("cuda")
    outputs = model1(**inputs)
    probs = outputs[0].softmax(1)
    return target_names[probs.argmax()], probs.argmax().cpu().numpy()
def multiclass_roc_auc_score(y_test, y_pred, average="macro"):
  lb = LabelBinarizer()
  lb.fit(y_test)
  y_test = lb.transform(y_test)
  y_pred = lb.transform(y_pred)
  return roc_auc_score(y_test, y_pred, average=average)
def compute_metrics(pred):
  labels = pred.label_ids
  preds = pred.predictions.argmax(-1)
  # calculate accuracy using sklearn's function
  acc = f1_score(labels, preds,average='weighted')
  precision, recall, fscore, support = precision_recall_fscore_support(labels, preds, average='weighted')
  return {
      'Accuracy' : round(accuracy_score(labels, preds),8),'Precision' : round(precision,8),
        'Recall' : round(recall,8), 'F-Score' : round(fscore,8), 
        'AUC ROC' : round(multiclass_roc_auc_score(labels, np.array(preds), average="macro"),8)
  }
path = r'/content/drive/My Drive/LegalArguementMining/'
df_train = create_dataframe(path + "Train_data")
df_train,df_untouched = train_test_split(df_train, stratify=df_train['Target'], test_size=0.2)
df_test = create_dataframe(path + "test_data")
df_unlabelled = create_dataframe(path + "Unlabeled_data")
df_unlabelled_new = pd.read_csv(path + "Unlabelled_new/df_unlabelled_new.csv")
df_test_new = pd.read_csv(r'/content/drive/My Drive/LegalArguementMining/test/test_bert2.csv',encoding='latin-1')
l = LabelEncoder().fit(df_train['Target'])
df_train['Target'] = l.transform(df_train['Target'])
df_untouched['Target'] = l.transform(df_untouched['Target'])
df_test['Target'] = l.transform(df_test['Target'])

print(df_train.shape)
print(df_untouched.shape)
print(df_unlabelled_new.shape)
df_train = pd.concat([df_train,df_untouched,df_test_new],axis=0)
print(df_train.shape)

train_texts , train_labels = df_train['Sentence'], df_train['Target']
valid_texts, valid_labels = df_test['Sentence'], df_test['Target']
test_texts, test_labels = df_untouched['Sentence'], df_untouched['Target']
target_names = df_train['Target'].value_counts().keys().tolist()

set_seed(1)
max_length = 512
model_name = "nlpaueb/bert-base-uncased-echr"
tokenizer = AutoTokenizer.from_pretrained("nlpaueb/legal-bert-base-uncased")
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=len(target_names)).to("cuda")
train_encodings = tokenizer(train_texts.to_list(), truncation=True, padding=True, max_length=max_length)
valid_encodings = tokenizer(valid_texts.to_list(), truncation=True, padding=True, max_length=max_length)

# convert our tokenized data into a torch Dataset
train_dataset = LegalDataset(train_encodings, train_labels.to_list())
valid_dataset = LegalDataset(valid_encodings, valid_labels.to_list())
# Out:
# (30168, 2)
# (7543, 2)
# (502560, 2)
# (37897, 2)
# Downloading tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/0.99k [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/217k [00:00<?, ?B/s]
# Downloading special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/0.98k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/420M [00:00<?, ?B/s]
# Some weights of the model checkpoint at
td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.247800</td>
#       <td>1.705899</td>
#       <td>0.710173</td>
#       <td>0.701123</td>
#       <td>0.710173</td>
#       <td>0.700563</td>
#       <td>0.763924</td>
#     </tr>
#     <tr>
#       <td>6400</td>
#       <td>0.197200</td>
#       <td>1.768303</td>
#       <td>0.689060</td>
#       <td>0.679641</td>
#       <td>0.689060</td>
#       <td>0.678696</td>
#       <td>0.746829</td>
#     </tr>
#     <tr>
#       <td>6800</td>
#       <td>0.230100</td>
#       <td>1.845429</td>
#       <td>0.696737</td>
#       <td>0.699319</td>
#       <td>0.696737</td>
#       <td>0.695550</td>
#       <td>0.776297</td>
#     </tr>
#     <tr>
#       <td>7200</td>
#       <td>0.229100</td>
#       <td>1.704965</td>
#       <td>0.715931</td>
#       <td>0.719365</td>
#       <td>0.715931</td>
#       <td>0.713318</td>
#       <td>0.779120</td>
#     </tr>
#     <tr>
#       <td>7600</td>
#       <td>0.177600</td>
#       <td>1.748782</td>
#       <td>0.712092</td>
#       <td>0.707157</td>
#       <td>0.712092</td>
#       <td>0.708009</td>
#       <td>0.786093</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.196300</td>
#       <td>1.801858</td>
#       <td>0.704415</td>
#       <td>0.704319</td>
#       <td>0.704415</td>
#       <td>0.702652</td>
#       <td>0.777039</td>
#     </tr>
#     <tr>
#       <td>8400</td>
#       <td>0.159200</td>
#       <td>2.232438</td>
#       <td>0.667946</td>
#       <td>0.703160</td>
#       <td>0.667946</td>
#       <td>0.664613</td>
#       <td>0.766504</td>
#     </tr>
#     <tr>
#       <td>8800</td>
#       <td>0.189700</td>
#       <td>1.811254</td>
#       <td>0.719770</td>
#       <td>0.710750</td>
#       <td>0.719770</td>
#       <td>0.709794</td>
#       <td>0.768797</td>
#     </tr>
#     <tr>
#       <td>9200</td>
#       <td>0.154400</td>
#       <td>1.708918</td>
#       <td>0.714012</td>
#       <td>0.711046</td>
#       <td>0.714012</td>
#       <td>0.705883</td>
#       <td>0.769074</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_echr/checkpoint-400
# Configuration saved in ./legal_results_echr/checkpoint-400/config.json
# Model weights saved in ./legal_results_echr/checkpoint-400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_echr/checkpoint-800
# Configuration saved in ./legal_results_echr/checkpoint-800/config.json
# Model weights saved in ./legal_results_echr/checkpoint-800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_echr/checkpoint-1200
# Configuration saved in ./legal_results_echr/checkpoint-1200/config.json
# Model weights saved in ./legal_results_echr/checkpoint-1200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_echr/checkpoint-1600
# Configuration saved in ./legal_results_echr/checkpoint-1600/config.json
# Model weights saved in ./legal_results_echr/checkpoint-1600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-2000
# Configuration saved in ./legal_results_echr/checkpoint-2000/config.json
# Model weights saved in ./legal_results_echr/checkpoint-2000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-2400
# Configuration saved in ./legal_results_echr/checkpoint-2400/config.json
# Model weights saved in ./legal_results_echr/checkpoint-2400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-2800
# Configuration saved in ./legal_results_echr/checkpoint-2800/config.json
# Model weights saved in ./legal_results_echr/checkpoint-2800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-3200
# Configuration saved in ./legal_results_echr/checkpoint-3200/config.json
# Model weights saved in ./legal_results_echr/checkpoint-3200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-3600
# Configuration saved in ./legal_results_echr/checkpoint-3600/config.json
# Model weights saved in ./legal_results_echr/checkpoint-3600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-4000
# Configuration saved in ./legal_results_echr/checkpoint-4000/config.json
# Model weights saved in ./legal_results_echr/checkpoint-4000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-4400
# Configuration saved in ./legal_results_echr/checkpoint-4400/config.json
# Model weights saved in ./legal_results_echr/checkpoint-4400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-4800
# Configuration saved in ./legal_results_echr/checkpoint-4800/config.json
# Model weights saved in ./legal_results_echr/checkpoint-4800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-5200
# Configuration saved in ./legal_results_echr/checkpoint-5200/config.json
# Model weights saved in ./legal_results_echr/checkpoint-5200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-5600
# Configuration saved in ./legal_results_echr/checkpoint-5600/config.json
# Model weights saved in ./legal_results_echr/checkpoint-5600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-6000
# Configuration saved in ./legal_results_echr/checkpoint-6000/config.json
# Model weights saved in ./legal_results_echr/checkpoint-6000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-6400
# Configuration saved in ./legal_results_echr/checkpoint-6400/config.json
# Model weights saved in ./legal_results_echr/checkpoint-6400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-6800
# Configuration saved in ./legal_results_echr/checkpoint-6800/config.json
# Model weights saved in ./legal_results_echr/checkpoint-6800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-7200
# Configuration saved in ./legal_results_echr/checkpoint-7200/config.json
# Model weights saved in ./legal_results_echr/checkpoint-7200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-7600
# Configuration saved in ./legal_results_echr/checkpoint-7600/config.json
# Model weights saved in ./legal_results_echr/checkpoint
td>
#     </tr>
#     <tr>
#       <td>13200</td>
#       <td>0.105500</td>
#       <td>1.792883</td>
#       <td>0.729367</td>
#       <td>0.717572</td>
#       <td>0.729367</td>
#       <td>0.719706</td>
#       <td>0.780151</td>
#     </tr>
#     <tr>
#       <td>13600</td>
#       <td>0.073100</td>
#       <td>1.940640</td>
#       <td>0.715931</td>
#       <td>0.726339</td>
#       <td>0.715931</td>
#       <td>0.717865</td>
#       <td>0.787372</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.078300</td>
#       <td>1.788690</td>
#       <td>0.735125</td>
#       <td>0.729786</td>
#       <td>0.735125</td>
#       <td>0.730836</td>
#       <td>0.790234</td>
#     </tr>
#     <tr>
#       <td>14400</td>
#       <td>0.068200</td>
#       <td>1.906838</td>
#       <td>0.717850</td>
#       <td>0.726863</td>
#       <td>0.717850</td>
#       <td>0.720434</td>
#       <td>0.785473</td>
#     </tr>
#     <tr>
#       <td>14800</td>
#       <td>0.044100<
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-9600
# Configuration saved in ./legal_results_echr/checkpoint-9600/config.json
# Model weights saved in ./legal_results_echr/checkpoint-9600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-10000
# Configuration saved in ./legal_results_echr/checkpoint-10000/config.json
# Model weights saved in ./legal_results_echr/checkpoint-10000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-10400
# Configuration saved in ./legal_results_echr/checkpoint-10400/config.json
# Model weights saved in ./legal_results_echr/checkpoint-10400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-10800
# Configuration saved in ./legal_results_echr/checkpoint-10800/config.json
# Model weights saved in ./legal_results_echr/checkpoint-10800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-11200
# Configuration saved in ./legal_results_echr/checkpoint-11200/config.json
# Model weights saved in ./legal_results_echr/checkpoint-11200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-11600
# Configuration saved in ./legal_results_echr/checkpoint-11600/config.json
# Model weights saved in ./legal_results_echr/checkpoint-11600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-12000
# Configuration saved in ./legal_results_echr/checkpoint-12000/config.json
# Model weights saved in ./legal_results_echr/checkpoint-12000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-12400
# Configuration saved in ./legal_results_echr/checkpoint-12400/config.json
# Model weights saved in ./legal_results_echr/checkpoint-12400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-12800
# Configuration saved in ./legal_results_echr/checkpoint-12800/config.json
# Model weights saved in ./legal_results_echr/checkpoint-12800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-13200
# Configuration saved in ./legal_results_echr/checkpoint-13200/config.json
# Model weights saved in ./legal_results_echr/checkpoint-13200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-13600
# Configuration saved in ./legal_results_echr/checkpoint-13600/config.json
# Model weights saved in ./legal_results_echr/checkpoint-13600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-14000
# Configuration saved in ./legal_results_echr/checkpoint-14000/config.json
# Model weights saved in ./legal_results_echr/checkpoint-14000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-14400
# Configuration saved in ./legal_results_echr/checkpoint-14400/config.json
# Model weights saved in ./legal_results_echr/checkpoint-14400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-14800
# Configuration saved in ./legal_results_echr/checkpoint-14800/config.json
# Model weights saved in ./legal_results_echr/checkpoint-14800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-15200
# Configuration saved in ./legal_results_echr/checkpoint-15200/config.json
# Model weights saved in ./legal_results_echr/checkpoint-15200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-15600
# Configuration saved in ./legal_results_echr/checkpoint-15600/config.json
# Model weights saved in ./legal_results_echr/checkpoint-15600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-16000
# Configuration saved in ./legal_results_echr/checkpoint-16000/config.json
# Model weights saved in ./legal_results_echr/checkpoint-16000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-16400
# Configuration saved in ./legal_results_echr/checkpoint-16400/config.json
# Model weights saved in ./legal_results_echr/checkpoint-16400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-16800
# Configuration saved in ./legal_results_echr/checkpoint-16800/config.json
# Model weights saved in ./legal_results_echr/checkpoint-16800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-17200
# Configuration saved in ./legal_results_echr/checkpoint-17200/config.json
# Model weights saved in ./legal_results_echr/checkpoint-17200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-17600
# Configuration saved in ./legal_results_echr/checkpoint-17600/config.json
# Model weights saved in ./legal_results_echr/checkpoint-17600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-18000
# Configuration saved in ./legal_results_echr/checkpoint-18000/config.json
# Model weights saved in ./legal_results_echr/checkpoint-18000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-18400
# Configuration saved in ./legal_results_echr/checkpoint-18400/config.json
# Model weights saved in ./legal_results_echr/checkpoint-18400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_echr/checkpoint-18800
# Configuration saved in ./legal_results_echr/checkpoint-18800/config.json
# Model weights saved in ./legal_results_echr/checkpoint-18800/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./legal_results_echr/checkpoint-1600 (score: 1.1649216413497925).
# TrainOutput(global_step=18952, training_loss=0.28806000920275987, metrics={'train_runtime': 3254.2326, 'train_samples_per_second': 46.582, 'train_steps_per_second': 5.824, 'total_flos': 2.44615010285892e+16, 'train_loss': 0.28806000920275987, 'epoch': 4.0})

# %%
trainer._load_from_checkpoint("/content/legal_results_echr/checkpoint-18800")
# Out:
# Loading model from /content/legal_results_echr/checkpoint-18800.

# %%
# evaluate the current model after training
trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
#     <div>
#
#       <progress value='54' max='27' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [27/27 00:35]
#     </div>
# {'eval_loss': 1.965091347694397,
#  'eval_Accuracy': 0.74664107,
#  'eval_Precision': 0.7430542,
#  'eval_Recall': 0.74664107,
#  'eval_F-Score': 0.74091901,
#  'eval_AUC ROC': 0.79585578,
#  'eval_runtime': 1.218,
#  'eval_samples_per_second': 427.765,
#  'eval_steps_per_second': 22.168,
#  'epoch': 4.0}

# %%
model1 = BertForSequenceClassification.from_pretrained("/content/legal_results_echr/checkpoint-18800", num_labels=len(target_names)).to("cuda")
pred = [get_prediction(i)[1] for i in df_test.Sentence.values.tolist()]
print('Accuracy of Test Dataset :',accuracy_score(pred, df_test.Target.values.tolist()))
# Out:
# loading configuration file /content/legal_results_echr/checkpoint-18800/config.json
# Model config BertConfig {
#   "_name_or_path": "nlpaueb/bert-base-uncased-echr",
#   "architectures": [
#     "BertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "eos_token_ids": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": null,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "torch_dtype": "float32",
#   "transformers_version": "4.21.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading weights file /content/legal_results_echr/checkpoint-18800/pytorch_model.bin
# All model checkpoint weights were used when initializing BertForSequenceClassification.
#
# All the weights of BertForSequenceClassification were initialized from the model checkpoint at /content/legal_results_echr/checkpoint-18800.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForSequenceClassification for predictions without further training.
# Accuracy of Test Dataset : 0.746641074856046

# %%
def confusion_matrixs(y, yp):
  k = sorted(list(set(y)))
  df = pd.DataFrame(index=k, columns=k)
  df.fillna(0, inplace=True)
  for i, j in zip(y, yp):
    df.loc[i, j] += 1
  sns.heatmap(df, annot=True)
  plt.plot()
def multiclass_roc_auc_score(y_test, y_pred, average="macro"):
  lb = LabelBinarizer()
  lb.fit(y_test)
  y_test = lb.transform(y_test)
  y_pred = lb.transform(y_pred)
  return roc_auc_score(y_test, y_pred, average=average)
print(confusion_matrix(df_test.Target.values.tolist(), pred))
precision, recall, fscore, support = precision_recall_fscore_support(df_test.Target.values.tolist(), pred, average='weighted')
print('Accuracy = ',round(accuracy_score(pred, df_test.Target.values.tolist()),8),'\nPrecision = ',round(precision,8),
      '\nRecall = ', round(recall,8), '\nF-Score = ',round(fscore,8), 
      '\nAUC ROC = ', round(multiclass_roc_auc_score(df_test.Target.values.tolist(),np.array(pred), average="macro"),8))
confusion_matrixs(df_test.Target.values.tolist(),np.array(pred))
print(classification_report(df_test.Target.values.tolist(),np.array(pred)))
# Out:
# [[ 40   3  27   0   2   2   3]
#  [  2  24   0   0   0   0   0]
#  [ 18   5 230   3   4   3   4]
#  [  3   0  12  48   0   0   2]
#  [  6   0   6   0  21   0   1]
#  [  3   1   7   0   2   4   1]
#  [  4   0   6   1   1   0  22]]
# Accuracy =  0.74664107
# Precision =  0.7430542
# Recall =  0.74664107
# F-Score =  0.74091901
# AUC ROC =  0.79585578
#               precision    recall  f1-score   support
#
#            0       0.53      0.52      0.52        77
#            1       0.73      0.92      0.81        26
#            2       0.80      0.86      0.83       267
#            3       0.92      0.74      0.82        65
#            4       0.70      0.62      0.66        34
#            5       0.44      0.22      0.30        18
#            6       0.67      0.65      0.66        34
#
#     accuracy                           0.75       521
#    macro avg       0.68      0.65      0.66       521
# weighted avg       0.74      0.75      0.74       521
