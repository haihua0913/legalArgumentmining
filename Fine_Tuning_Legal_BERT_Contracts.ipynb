# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.21.1-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 14.4 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 12.3 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 71.0 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.8.1 tokenizers-0.12.1 transformers-4.21.1

# %%
import pandas as pd, glob, re, string,seaborn as sns, random, numpy as np, os, transformers, torch, matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, LabelBinarizer
from sklearn.metrics import accuracy_score,confusion_matrix,precision_recall_fscore_support,roc_auc_score, classification_report, auc, roc_curve,f1_score
from tqdm import tqdm
# specify GPU
device = torch.device("cuda")
from transformers.file_utils import is_tf_available, is_torch_available, is_torch_tpu_available
from transformers import BertTokenizerFast, BertForSequenceClassification ,BertTokenizer, AutoModel, AutoTokenizer,Trainer, TrainingArguments,AutoModelForPreTraining,AutoModelForSequenceClassification

# %%
def create_dataframe(path):
    train_files = glob.glob(path + "/*.csv")
    df = pd.concat([pd.read_csv(filename, index_col=None, header=0) for filename in train_files], axis=0, ignore_index=True)
    df = df.drop(['Unnamed: 0'],axis=1)
    return df
def set_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    if is_torch_available():
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        # safe to call this function even if cuda is not available
    if is_tf_available():
        import tensorflow as tf
        tf.random.set_seed(seed)
class LegalDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels
    def __getitem__(self, idx):
        item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
        item["labels"] = torch.tensor([self.labels[idx]])
        return item
    def __len__(self):
        return len(self.labels)
def get_prediction(text):
    inputs = tokenizer(text, padding=True, truncation=True, max_length=max_length, return_tensors="pt").to("cuda")
    outputs = model1(**inputs)
    probs = outputs[0].softmax(1)
    return target_names[probs.argmax()], probs.argmax().cpu().numpy()
def multiclass_roc_auc_score(y_test, y_pred, average="macro"):
  lb = LabelBinarizer()
  lb.fit(y_test)
  y_test = lb.transform(y_test)
  y_pred = lb.transform(y_pred)
  return roc_auc_score(y_test, y_pred, average=average)
def compute_metrics(pred):
  labels = pred.label_ids
  preds = pred.predictions.argmax(-1)
  # calculate accuracy using sklearn's function
  acc = f1_score(labels, preds,average='weighted')
  precision, recall, fscore, support = precision_recall_fscore_support(labels, preds, average='weighted')
  return {
      'Accuracy' : round(accuracy_score(labels, preds),8),'Precision' : round(precision,8),
        'Recall' : round(recall,8), 'F-Score' : round(fscore,8), 
        'AUC ROC' : round(multiclass_roc_auc_score(labels, np.array(preds), average="macro"),8)
  }
path = r'/content/drive/My Drive/LegalArguementMining/'
df_train = create_dataframe(path + "Train_data")
df_train,df_untouched = train_test_split(df_train, stratify=df_train['Target'], test_size=0.2)
df_test = create_dataframe(path + "test_data")
df_unlabelled = create_dataframe(path + "Unlabeled_data")
df_unlabelled_new = pd.read_csv(path + "Unlabelled_new/df_unlabelled_new.csv")
df_test_new = pd.read_csv(r'/content/drive/My Drive/LegalArguementMining/test/test_bert2.csv',encoding='latin-1')
l = LabelEncoder().fit(df_train['Target'])
df_train['Target'] = l.transform(df_train['Target'])
df_untouched['Target'] = l.transform(df_untouched['Target'])
df_test['Target'] = l.transform(df_test['Target'])

print(df_train.shape)
print(df_untouched.shape)
print(df_unlabelled_new.shape)
df_train = pd.concat([df_train,df_untouched,df_test_new],axis=0)
print(df_train.shape)

train_texts , train_labels = df_train['Sentence'], df_train['Target']
valid_texts, valid_labels = df_test['Sentence'], df_test['Target']
test_texts, test_labels = df_untouched['Sentence'], df_untouched['Target']
target_names = df_train['Target'].value_counts().keys().tolist()

set_seed(1)
max_length = 512
model_name = "nlpaueb/bert-base-uncased-contracts"
tokenizer = AutoTokenizer.from_pretrained("nlpaueb/legal-bert-base-uncased")
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=len(target_names)).to("cuda")
train_encodings = tokenizer(train_texts.to_list(), truncation=True, padding=True, max_length=max_length)
valid_encodings = tokenizer(valid_texts.to_list(), truncation=True, padding=True, max_length=max_length)

# convert our tokenized data into a torch Dataset
train_dataset = LegalDataset(train_encodings, train_labels.to_list())
valid_dataset = LegalDataset(valid_encodings, valid_labels.to_list())
# Out:
# (30168, 2)
# (7543, 2)
# (502560, 2)
# (37897, 2)
# Downloading tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/0.99k [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/217k [00:00<?, ?B/s]
# Downloading special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/0.98k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/420M [00:00<?, ?B/s]
# Some weights of the model checkpoint at nlpaueb/bert-base-uncased-contracts were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at nlpaueb/bert-base-uncased-contracts and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir='./legal_results_contracts',          # output directory
    num_train_epochs=4,              # total number of training epochs
    per_device_train_batch_size=8,  # batch size per device during training
    per_device_eval_batch_size=20,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir='./legal_logs_contracts',            # directory for storing logs
    load_best_model_at_end=True,     # load the best model when finished training (default metric is loss)
    # but you can specify `metric_for_best_model` argument to change to accuracy or other metric
    logging_steps=400,               # log & save weights each logging_steps
    save_steps=400,
    evaluation_strategy="steps",     # evaluate each `logging_steps`
)
trainer = Trainer(
    model=model,                         # the instantiated Transformers model to be trained
    args=training_args,                  # training arguments, defined above
    train_dataset=train_dataset,         # training dataset
    eval_dataset=valid_dataset,          # evaluation dataset
    compute_metrics=compute_metrics,     # the callback that computes metrics of interest
)

# %%
# train the model
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 37897
#   Num Epochs = 4
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 18952
#     <div>
#
#       <progress value='18952' max='18952' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18952/18952 54:09, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F-score</th>
#       <th>Auc roc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>400</td>
#       <td>1.531200</td>
#       <td>1.443038</td>
#       <td>0.520154</td>
#       <td>0.372957</td>
#       <td>0.520154</td>
#       <td>0.399116</td>
#       <td>0.529860</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.512200</td>
#       <td>1.468249</td>
#       <td>0.514395</td>
#       <td>0.387897</td>
#       <td>0.514395</td>
#       <td>0.351509</td>
#       <td>0.501380</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>1.459600</td>
#       <td>1.359643</td>
#       <td>0.525912</td>
#       <td>0.367190</td>
#       <td>0.525912</td>
#       <td>0.404354</td>
#       <td>0.529185</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>1.351400</td>
#       <td>1.289547</td>
#       <td>0.531670</td>
#       <td>0.497016</td>
#       <td>0.531670</td>
#       <td>0.410269</td>
#       <td>0.529809</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.185600</td>
#       <td>1.280009</td>
#       <td>0.533589</td>
#       <td>0.545767</td>
#       <td>0.533589</td>
#       <td>0.506553</td>
#       <td>0.595804</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>1.188900</td>
#       <td>1.384312</td>
#       <td>0.566219</td>
#       <td>0.519466</td>
#       <td>0.566219</td>
#       <td>0.485024</td>
#       <td>0.580075</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>1.172500</td>
#       <td>1.390612</td>
#       <td>0.550864</td>
#       <td>0.532866</td>
#       <td>0.550864</td>
#       <td>0.476696</td>
#       <td>0.574133</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>1.165500</td>
#       <td>1.460930</td>
#       <td>0.570058</td>
#       <td>0.514842</td>
#       <td>0.570058</td>
#       <td>0.526632</td>
#       <td>0.610125</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>1.093200</td>
#       <td>1.309872</td>
#       <td>0.593090</td>
#       <td>0.560583</td>
#       <td>0.593090</td>
#       <td>0.544775</td>
#       <td>0.622590</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.995200</td>
#       <td>1.282066</td>
#       <td>0.575816</td>
#       <td>0.598619</td>
#       <td>0.575816</td>
#       <td>0.571308</td>
#       <td>0.664696</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.885700</td>
#       <td>1.308696</td>
#       <td>0.606526</td>
#       <td>0.574579</td>
#       <td>0.606526</td>
#       <td>0.581552</td>
#       <td>0.645279</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.851400</td>
#       <td>1.397440</td>
#       <td>0.585413</td>
#       <td>0.574897</td>
#       <td>0.585413</td>
#       <td>0.571893</td>
#       <td>0.656566</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.763700</td>
#       <td>1.420536</td>
#       <td>0.598848</td>
#       <td>0.590092</td>
#       <td>0.598848</td>
#       <td>0.586819</td>
#       <td>0.671964</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>0.769400</td>
#       <td>1.479935</td>
#       <td>0.619962</td>
#       <td>0.598199</td>
#       <td>0.619962</td>
#       <td>0.595162</td>
#       <td>0.660734</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.781300</td>
#       <td>1.358182</td>
#       <td>0.589251</td>
#       <td>0.597316</td>
#       <td>0.589251</td>
#       <td>0.580348</td>
#       <td>0.650725</td>
#     </tr>
#     <tr>
#       <td>6400</td>
#       <td>0.719200</td>
#       <td>1.386618</td>
#       <td>0.612284</td>
#       <td>0.623024</td>
#       <td>0.612284</td>
#       <td>0.609725</td>
#       <td>0.688812</td>
#     </tr>
#     <tr>
#       <td>6800</td>
#       <td>0.716500</td>
#       <td>1.503733</td>
#       <td>0.618042</td>
#       <td>0.600080</td>
#       <td>0.618042</td>
#       <td>0.602781</td>
#       <td>0.688751</td>
#     </tr>
#     <tr>
#       <td>7200</td>
#       <td>0.676600</td>
#       <td>1.485024</td>
#       <td>0.612284</td>
#       <td>0.593060</td>
#       <td>0.612284</td>
#       <td>0.594260</td>
#       <td>0.693534</td>
#     </tr>
#     <tr>
#       <td>7600</td>
#       <td>0.660600</td>
#       <td>1.572343</td>
#       <td>0.614203</td>
#       <td>0.616349</td>
#       <td>0.614203</td>
#       <td>0.598339</td>
#       <td>0.659962</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.606200</td>
#       <td>1.647852</td>
#       <td>0.627639</td>
#       <td>0.620307</td>
#       <td>0.627639</td>
#       <td>0.616816</td>
#       <td>0.688138</td>
#     </tr>
#     <tr>
#       <td>8400</td>
#       <td>0.614400</td>
#       <td>1.550664</td>
#       <td>0.619962</td>
#       <td>0.645498</td>
#       <td>0.619962</td>
#       <td>0.620705</td>
#       <td>0.696499</td>
#     </tr>
#     <tr>
#       <td>8800</td>
#       <td>0.596600</td>
#       <td>1.670195</td>
#       <td>0.627639</td>
#       <td>0.636761</td>
#       <td>0.627639</td>
#       <td>0.621331</td>
#       <td>0.706567</td>
#     </tr>
#     <tr>
#       <td>9200</td>
#       <td>0.551500</td>
#       <td>1.720186</td>
#       <td>0.660269</td>
#       <td>0.649417</td>
#       <td>0.660269</td>
#       <td>0.627230</td>
#       <td>0.690764</td>
#     </tr>
#     <tr>
#       <td>9600</td>
#       <td>0.544200</td>
#       <td>1.806524</td>
#       <td>0.641075</td>
#       <td>0.652106</td>
#       <td>0.641075</td>
#       <td>0.642397</td>
#       <td>0.717267</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.537200</td>
#       <td>1.552688</td>
#       <td>0.660269</td>
#       <td>0.659657</td>
#       <td>0.660269</td>
#       <td>0.652443</td>
#       <td>0.724924</td>
#     </tr>
#     <tr>
#       <td>10400</td>
#       <td>0.548500</td>
#       <td>1.699143</td>
#       <td>0.656430</td>
#       <td>0.661757</td>
#       <td>0.656430</td>
#       <td>0.649059</td>
#       <td>0.718079</td>
#     </tr>
#     <tr>
#       <td>10800</td>
#       <td>0.518200</td>
#       <td>1.774279</td>
#       <td>0.666027</td>
#       <td>0.679002</td>
#       <td>0.666027</td>
#       <td>0.662852</td>
#       <td>0.723636</td>
#     </tr>
#     <tr>
#       <td>11200</td>
#       <td>0.527900</td>
#       <td>1.662684</td>
#       <td>0.666027</td>
#       <td>0.671437</td>
#       <td>0.666027</td>
#       <td>0.654597</td>
#       <td>0.709789</td>
#     </tr>
#     <tr>
#       <td>11600</td>
#       <td>0.487300</td>
#       <td>1.667769</td>
#       <td>0.664107</td>
#       <td>0.659112</td>
#       <td>0.664107</td>
#       <td>0.660159</td>
#       <td>0.730748</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.461000</td>
#       <td>1.688764</td>
#       <td>0.658349</td>
#       <td>0.664250</td>
#       <td>0.658349</td>
#       <td>0.649264</td>
#       <td>0.714569</td>
#     </tr>
#     <tr>
#       <td>12400</td>
#       <td>0.470200</td>
#       <td>1.746137</td>
#       <td>0.658349</td>
#       <td>0.657839</td>
#       <td>0.658349</td>
#       <td>0.648136</td>
#       <td>0.714158</td>
#     </tr>
#     <tr>
#       <td>12800</td>
#       <td>0.450100</td>
#       <td>1.831290</td>
#       <td>0.669866</td>
#       <td>0.657658</td>
#       <td>0.669866</td>
#       <td>0.655217</td>
#       <td>0.712627</td>
#     </tr>
#     <tr>
#       <td>13200</td>
#       <td>0.481100</td>
#       <td>1.765255</td>
#       <td>0.669866</td>
#       <td>0.677768</td>
#       <td>0.669866</td>
#       <td>0.655895</td>
#       <td>0.712903</td>
#     </tr>
#     <tr>
#       <td>13600</td>
#       <td>0.417700</td>
#       <td>1.809486</td>
#       <td>0.662188</td>
#       <td>0.660914</td>
#       <td>0.662188</td>
#       <td>0.646789</td>
#       <td>0.704614</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.443100</td>
#       <td>1.763658</td>
#       <td>0.679463</td>
#       <td>0.682554</td>
#       <td>0.679463</td>
#       <td>0.667390</td>
#       <td>0.714764</td>
#     </tr>
#     <tr>
#       <td>14400</td>
#       <td>0.405700</td>
#       <td>1.675777</td>
#       <td>0.677543</td>
#       <td>0.686901</td>
#       <td>0.677543</td>
#       <td>0.663127</td>
#       <td>0.717497</td>
#     </tr>
#     <tr>
#       <td>14800</td>
#       <td>0.424400<
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_contracts/checkpoint-400
# Configuration saved in ./legal_results_contracts/checkpoint-400/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_contracts/checkpoint-800
# Configuration saved in ./legal_results_contracts/checkpoint-800/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_contracts/checkpoint-1200
# Configuration saved in ./legal_results_contracts/checkpoint-1200/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-1200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_contracts/checkpoint-1600
# Configuration saved in ./legal_results_contracts/checkpoint-1600/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-1600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_contracts/checkpoint-2000
# Configuration saved in ./legal_results_contracts/checkpoint-2000/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-2000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-2400
# Configuration saved in ./legal_results_contracts/checkpoint-2400/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-2400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_contracts/checkpoint-2800
# Configuration saved in ./legal_results_contracts/checkpoint-2800/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-2800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_contracts/checkpoint-3200
# Configuration saved in ./legal_results_contracts/checkpoint-3200/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-3200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_contracts/checkpoint-3600
# Configuration saved in ./legal_results_contracts/checkpoint-3600/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-3600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_contracts/checkpoint-4000
# Configuration saved in ./legal_results_contracts/checkpoint-4000/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-4000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-4400
# Configuration saved in ./legal_results_contracts/checkpoint-4400/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-4400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-4800
# Configuration saved in ./legal_results_contracts/checkpoint-4800/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-4800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-5200
# Configuration saved in ./legal_results_contracts/checkpoint-5200/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-5200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-5600
# Configuration saved in ./legal_results_contracts/checkpoint-5600/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-5600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-6000
# Configuration saved in ./legal_results_contracts/checkpoint-6000/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-6000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-6400
# Configuration saved in ./legal_results_contracts/checkpoint-6400/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-6400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-6800
# Configuration saved in ./legal_results_contracts/checkpoint-6800/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-6800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-7200
# Configuration saved in ./legal_results_contracts/checkpoint-7200/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-7200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-7600
# Configuration saved in ./legal_results_contracts/checkpoint-7600/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-7600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-8000
# Configuration saved in ./legal_results_contracts/checkpoint-8000/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-8000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-8400
# Configuration saved in ./legal_results_contracts/checkpoint-8400/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-8400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-8800
# Configuration saved in ./legal_results_contracts/checkpoint-8800/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-8800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-9200
# Configuration saved in ./legal_results_contracts/checkpoint-9200/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-9200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-9600
# Configuration saved in ./legal_results_contracts/checkpoint-9600/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-9600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-10000
# Configuration saved in ./legal_results_contracts/checkpoint-10000/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-10000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-10400
# Configuration saved in ./legal_results_contracts/checkpoint-10400/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-10400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-10800
# Configuration saved in ./legal_results_contracts/checkpoint-10800/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-10800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-11200
# Configuration saved in ./legal_results_contracts/checkpoint-11200/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-11200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-11600
# Configuration saved in ./legal_results_contracts/checkpoint-11600/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-11600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-12000
# Configuration saved in ./legal_results_contracts/checkpoint-12000/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-12000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-12400
# Configuration saved in ./legal_results_contracts/checkpoint-12400/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-12400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-12800
# Configuration saved in ./legal_results_contracts/checkpoint-12800/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-12800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-13200
# Configuration saved in ./legal_results_contracts/checkpoint-13200/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-13200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-13600
# Configuration saved in ./legal_results_contracts/checkpoint-13600/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-13600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-14000
# Configuration saved in ./legal_results_contracts/checkpoint-14000/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-14000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-14400
# Configuration saved in ./legal_results_contracts/checkpoint-14400/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-14400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-14800
# Configuration saved in ./legal_results_contracts/checkpoint-14800/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-14800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-15200
# Configuration saved in ./legal_results_contracts/checkpoint-15200/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-15200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-15600
# Configuration saved in ./legal_results_contracts/checkpoint-15600/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-15600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-16000
# Configuration saved in ./legal_results_contracts/checkpoint-16000/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-16000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-16400
# Configuration saved in ./legal_results_contracts/checkpoint-16400/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-16400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-16800
# Configuration saved in ./legal_results_contracts/checkpoint-16800/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-16800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-17200
# Configuration saved in ./legal_results_contracts/checkpoint-17200/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-17200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-17600
# Configuration saved in ./legal_results_contracts/checkpoint-17600/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-17600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-18000
# Configuration saved in ./legal_results_contracts/checkpoint-18000/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-18000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-18400
# Configuration saved in ./legal_results_contracts/checkpoint-18400/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-18400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# Saving model checkpoint to ./legal_results_contracts/checkpoint-18800
# Configuration saved in ./legal_results_contracts/checkpoint-18800/config.json
# Model weights saved in ./legal_results_contracts/checkpoint-18800/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./legal_results_contracts/checkpoint-2000 (score: 1.2800089120864868).
# TrainOutput(global_step=18952, training_loss=0.6768175115460532, metrics={'train_runtime': 3252.4282, 'train_samples_per_second': 46.608, 'train_steps_per_second': 5.827, 'total_flos': 2.44615010285892e+16, 'train_loss': 0.6768175115460532, 'epoch': 4.0})

# %%
trainer._load_from_checkpoint("/content/legal_results_contracts/checkpoint-14800")
# Out:
# Loading model from /content/legal_results_contracts/checkpoint-14800.

# %%
# evaluate the current model after training
trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
#     <div>
#
#       <progress value='54' max='27' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [27/27 02:04]
#     </div>
# {'eval_loss': 1.5976660251617432,
#  'eval_Accuracy': 0.68522073,
#  'eval_Precision': 0.67107129,
#  'eval_Recall': 0.68522073,
#  'eval_F-Score': 0.6632662,
#  'eval_AUC ROC': 0.7276939,
#  'eval_runtime': 1.2217,
#  'eval_samples_per_second': 426.457,
#  'eval_steps_per_second': 22.1,
#  'epoch': 4.0}

# %%
model1 = BertForSequenceClassification.from_pretrained("/content/legal_results_contracts/checkpoint-14800", num_labels=len(target_names)).to("cuda")
pred = [get_prediction(i)[1] for i in df_test.Sentence.values.tolist()]
print('Accuracy of Test Dataset :',accuracy_score(pred, df_test.Target.values.tolist()))
# Out:
# loading configuration file /content/legal_results_contracts/checkpoint-14800/config.json
# Model config BertConfig {
#   "_name_or_path": "nlpaueb/bert-base-uncased-contracts",
#   "architectures": [
#     "BertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "eos_token_ids": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": null,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "torch_dtype": "float32",
#   "transformers_version": "4.21.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading weights file /content/legal_results_contracts/checkpoint-14800/pytorch_model.bin
# All model checkpoint weights were used when initializing BertForSequenceClassification.
#
# All the weights of BertForSequenceClassification were initialized from the model checkpoint at /content/legal_results_contracts/checkpoint-14800.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForSequenceClassification for predictions without further training.
# Accuracy of Test Dataset : 0.6852207293666027

# %%
def confusion_matrixs(y, yp):
  k = sorted(list(set(y)))
  df = pd.DataFrame(index=k, columns=k)
  df.fillna(0, inplace=True)
  for i, j in zip(y, yp):
    df.loc[i, j] += 1
  sns.heatmap(df, annot=True)
  plt.plot()
def multiclass_roc_auc_score(y_test, y_pred, average="macro"):
  lb = LabelBinarizer()
  lb.fit(y_test)
  y_test = lb.transform(y_test)
  y_pred = lb.transform(y_pred)
  return roc_auc_score(y_test, y_pred, average=average)
print(confusion_matrix(df_test.Target.values.tolist(), pred))
precision, recall, fscore, support = precision_recall_fscore_support(df_test.Target.values.tolist(), pred, average='weighted')
print('Accuracy = ',round(accuracy_score(pred, df_test.Target.values.tolist()),8),'\nPrecision = ',round(precision,8),
      '\nRecall = ', round(recall,8), '\nF-Score = ',round(fscore,8), 
      '\nAUC ROC = ', round(multiclass_roc_auc_score(df_test.Target.values.tolist(),np.array(pred), average="macro"),8))
confusion_matrixs(df_test.Target.values.tolist(),np.array(pred))
print(classification_report(df_test.Target.values.tolist(),np.array(pred)))
# Out:
# [[ 25   4  33   4   1   1   9]
#  [  3  21   1   0   0   0   1]
#  [  9   2 241   4   1   2   8]
#  [  1   1  28  33   0   0   2]
#  [  3   0  10   1  14   1   5]
#  [  5   2   4   2   1   2   2]
#  [  4   0   5   2   1   1  21]]
# Accuracy =  0.68522073
# Precision =  0.67107129
# Recall =  0.68522073
# F-Score =  0.6632662
# AUC ROC =  0.7276939
#               precision    recall  f1-score   support
#
#            0       0.50      0.32      0.39        77
#            1       0.70      0.81      0.75        26
#            2       0.75      0.90      0.82       267
#            3       0.72      0.51      0.59        65
#            4       0.78      0.41      0.54        34
#            5       0.29      0.11      0.16        18
#            6       0.44      0.62      0.51        34
#
#     accuracy                           0.69       521
#    macro avg       0.60      0.53      0.54       521
# weighted avg       0.67      0.69      0.66       521
