# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.21.1-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 14.2 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 72.2 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 13.9 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.8.1 tokenizers-0.12.1 transformers-4.21.1

# %%
import pandas as pd, glob, re, string,seaborn as sns, random, numpy as np, os, transformers, torch, matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, LabelBinarizer
from sklearn.metrics import accuracy_score,confusion_matrix,precision_recall_fscore_support,roc_auc_score, classification_report, auc, roc_curve,f1_score
from tqdm import tqdm
# specify GPU
device = torch.device("cuda")
from transformers.file_utils import is_tf_available, is_torch_available, is_torch_tpu_available
from transformers import BertTokenizerFast, BertForSequenceClassification ,BertTokenizer, AutoModel, AutoTokenizer,Trainer, TrainingArguments,AutoModelForPreTraining,AutoModelForSequenceClassification

# %%
def create_dataframe(path):
    train_files = glob.glob(path + "/*.csv")
    df = pd.concat([pd.read_csv(filename, index_col=None, header=0) for filename in train_files], axis=0, ignore_index=True)
    df = df.drop(['Unnamed: 0'],axis=1)
    return df
def set_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    if is_torch_available():
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        # safe to call this function even if cuda is not available
    if is_tf_available():
        import tensorflow as tf
        tf.random.set_seed(seed)
class LegalDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels
    def __getitem__(self, idx):
        item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
        item["labels"] = torch.tensor([self.labels[idx]])
        return item
    def __len__(self):
        return len(self.labels)
def get_prediction(text):
    inputs = tokenizer(text, padding=True, truncation=True, max_length=max_length, return_tensors="pt").to("cuda")
    outputs = model1(**inputs)
    probs = outputs[0].softmax(1)
    return target_names[probs.argmax()], probs.argmax().cpu().numpy()
def multiclass_roc_auc_score(y_test, y_pred, average="macro"):
  lb = LabelBinarizer()
  lb.fit(y_test)
  y_test = lb.transform(y_test)
  y_pred = lb.transform(y_pred)
  return roc_auc_score(y_test, y_pred, average=average)
def compute_metrics(pred):
  labels = pred.label_ids
  preds = pred.predictions.argmax(-1)
  # calculate accuracy using sklearn's function
  acc = f1_score(labels, preds,average='weighted')
  precision, recall, fscore, support = precision_recall_fscore_support(labels, preds, average='weighted')
  return {
      'Accuracy' : round(accuracy_score(labels, preds),8),'Precision' : round(precision,8),
        'Recall' : round(recall,8), 'F-Score' : round(fscore,8), 
        'AUC ROC' : round(multiclass_roc_auc_score(labels, np.array(preds), average="macro"),8)
  }
path = r'/content/drive/My Drive/LegalArguementMining/'
df_train = create_dataframe(path + "Train_data")
df_train,df_untouched = train_test_split(df_train, stratify=df_train['Target'], test_size=0.2)
df_test = create_dataframe(path + "test_data")
df_unlabelled = create_dataframe(path + "Unlabeled_data")
df_unlabelled_new = pd.read_csv(path + "Unlabelled_new/df_unlabelled_new.csv")
df_test_new = pd.read_csv(r'/content/drive/My Drive/LegalArguementMining/test/test_bert2.csv',encoding='latin-1')
l = LabelEncoder().fit(df_train['Target'])
df_train['Target'] = l.transform(df_train['Target'])
df_untouched['Target'] = l.transform(df_untouched['Target'])
df_test['Target'] = l.transform(df_test['Target'])

print(df_train.shape)
print(df_untouched.shape)
print(df_unlabelled_new.shape)
df_train = pd.concat([df_train,df_untouched,df_test_new],axis=0)
print(df_train.shape)

train_texts , train_labels = df_train['Sentence'], df_train['Target']
valid_texts, valid_labels = df_test['Sentence'], df_test['Target']
test_texts, test_labels = df_untouched['Sentence'], df_untouched['Target']
target_names = df_train['Target'].value_counts().keys().tolist()

set_seed(1)
max_length = 512
model_name = "nlpaueb/bert-base-uncased-eurlex"
tokenizer = AutoTokenizer.from_pretrained("nlpaueb/legal-bert-base-uncased")
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=len(target_names)).to("cuda")
train_encodings = tokenizer(train_texts.to_list(), truncation=True, padding=True, max_length=max_length)
valid_encodings = tokenizer(valid_texts.to_list(), truncation=True, padding=True, max_length=max_length)

# convert our tokenized data into a torch Dataset
train_dataset = LegalDataset(train_encodings, train_labels.to_list())
valid_dataset = LegalDataset(valid_encodings, valid_labels.to_list())
# Out:
# (30168, 2)
# (7543, 2)
# (502560, 2)
# (37897, 2)
# Downloading tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/0.99k [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/217k [00:00<?, ?B/s]
# Downloading special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/0.98k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/420M [00:00<?, ?B/s]
# Some weights of the model checkpoint at nlpaueb/bert-base-uncased-eurlex were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at nlpaueb/bert-base-uncased-eurlex and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir='./legal_results_eurlex',          # output directory
    num_train_epochs=4,              # total number of training epochs
    per_device_train_batch_size=8,  # batch size per device during training
    per_device_eval_batch_size=20,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir='./legal_logs_eurlex',            # directory for storing logs
    load_best_model_at_end=True,     # load the best model when finished training (default metric is loss)
    # but you can specify `metric_for_best_model` argument to change to accuracy or other metric
    logging_steps=400,               # log & save weights each logging_steps
    save_steps=400,
    evaluation_strategy="steps",     # evaluate each `logging_steps`
)
trainer = Trainer(
    model=model,                         # the instantiated Transformers model to be trained
    args=training_args,                  # training arguments, defined above
    train_dataset=train_dataset,         # training dataset
    eval_dataset=valid_dataset,          # evaluation dataset
    compute_metrics=compute_metrics,     # the callback that computes metrics of interest
)

# %%
# train the model
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 37897
#   Num Epochs = 4
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 18952
#     <div>
#
#       <progress value='18952' max='18952' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18952/18952 54:15, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F-score</th>
#       <th>Auc roc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>400</td>
#       <td>1.549600</td>
#       <td>1.500723</td>
#       <td>0.518234</td>
#       <td>0.388913</td>
#       <td>0.518234</td>
#       <td>0.359622</td>
#       <td>0.504140</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.527400</td>
#       <td>1.505326</td>
#       <td>0.523992</td>
#       <td>0.328972</td>
#       <td>0.523992</td>
#       <td>0.380464</td>
#       <td>0.512977</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>1.499100</td>
#       <td>1.500490</td>
#       <td>0.523992</td>
#       <td>0.354100</td>
#       <td>0.523992</td>
#       <td>0.373722</td>
#       <td>0.509486</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>1.522700</td>
#       <td>1.514814</td>
#       <td>0.512476</td>
#       <td>0.262632</td>
#       <td>0.512476</td>
#       <td>0.347287</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.531800</td>
#       <td>1.499374</td>
#       <td>0.520154</td>
#       <td>0.389424</td>
#       <td>0.520154</td>
#       <td>0.363524</td>
#       <td>0.505520</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>1.528000</td>
#       <td>1.492013</td>
#       <td>0.523992</td>
#       <td>0.360297</td>
#       <td>0.523992</td>
#       <td>0.371357</td>
#       <td>0.508530</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>1.541000</td>
#       <td>1.502550</td>
#       <td>0.523992</td>
#       <td>0.354100</td>
#       <td>0.523992</td>
#       <td>0.373722</td>
#       <td>0.509486</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>1.479500</td>
#       <td>1.485438</td>
#       <td>0.523992</td>
#       <td>0.346684</td>
#       <td>0.523992</td>
#       <td>0.373867</td>
#       <td>0.509610</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>1.497600</td>
#       <td>1.452750</td>
#       <td>0.533589</td>
#       <td>0.337499</td>
#       <td>0.533589</td>
#       <td>0.403943</td>
#       <td>0.528023</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>1.472400</td>
#       <td>1.458038</td>
#       <td>0.518234</td>
#       <td>0.322868</td>
#       <td>0.518234</td>
#       <td>0.393457</td>
#       <td>0.525128</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>1.475500</td>
#       <td>1.451322</td>
#       <td>0.516315</td>
#       <td>0.320507</td>
#       <td>0.516315</td>
#       <td>0.391544</td>
#       <td>0.523997</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>1.469800</td>
#       <td>1.454721</td>
#       <td>0.516315</td>
#       <td>0.320958</td>
#       <td>0.516315</td>
#       <td>0.391320</td>
#       <td>0.523748</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>1.491600</td>
#       <td>1.486860</td>
#       <td>0.525912</td>
#       <td>0.334310</td>
#       <td>0.525912</td>
#       <td>0.389570</td>
#       <td>0.518056</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>1.489900</td>
#       <td>1.475749</td>
#       <td>0.531670</td>
#       <td>0.349326</td>
#       <td>0.531670</td>
#       <td>0.388848</td>
#       <td>0.516336</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>1.502400</td>
#       <td>1.490732</td>
#       <td>0.522073</td>
#       <td>0.349421</td>
#       <td>0.522073</td>
#       <td>0.370215</td>
#       <td>0.508106</td>
#     </tr>
#     <tr>
#       <td>6400</td>
#       <td>1.496000</td>
#       <td>1.494666</td>
#       <td>0.522073</td>
#       <td>0.349421</td>
#       <td>0.522073</td>
#       <td>0.370215</td>
#       <td>0.508106</td>
#     </tr>
#     <tr>
#       <td>6800</td>
#       <td>1.495900</td>
#       <td>1.496630</td>
#       <td>0.520154</td>
#       <td>0.389424</td>
#       <td>0.520154</td>
#       <td>0.363524</td>
#       <td>0.505520</td>
#     </tr>
#     <tr>
#       <td>7200</td>
#       <td>1.531300</td>
#       <td>1.507707</td>
#       <td>0.520154</td>
#       <td>0.389424</td>
#       <td>0.520154</td>
#       <td>0.363524</td>
#       <td>0.505520</td>
#     </tr>
#     <tr>
#       <td>7600</td>
#       <td>1.519600</td>
#       <td>1.519961</td>
#       <td>0.512476</td>
#       <td>0.262632</td>
#       <td>0.512476</td>
#       <td>0.347287</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>1.528700</td>
#       <td>1.508011</td>
#       <td>0.512476</td>
#       <td>0.262632</td>
#       <td>0.512476</td>
#       <td>0.347287</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>8400</td>
#       <td>1.531700</td>
#       <td>1.508569</td>
#       <td>0.512476</td>
#       <td>0.262632</td>
#       <td>0.512476</td>
#       <td>0.347287</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>8800</td>
#       <td>1.531800</td>
#       <td>1.508004</td>
#       <td>0.512476</td>
#       <td>0.262632</td>
#       <td>0.512476</td>
#       <td>0.347287</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>9200</td>
#       <td>1.529300</td>
#       <td>1.508603</td>
#       <td>0.512476</td>
#       <td>0.262632</td>
#       <td>0.512476</td>
#       <td>0.347287</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>9600</td>
#       <td>1.524500</td>
#       <td>1.508584</td>
#       <td>0.512476</td>
#       <td>0.262632</td>
#       <td>0.512476</td>
#       <td>0.347287</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>1.537700</td>
#       <td>1.510177</td>
#       <td>0.512476</td>
#       <td>0.262632</td>
#       <td>0.512476</td>
#       <td>0.347287</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>10400</td>
#       <td>1.537200</td>
#       <td>1.515493</td>
#       <td>0.512476</td>
#       <td>0.262632</td>
#       <td>0.512476</td>
#       <td>0.347287</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>10800</td>
#       <td>1.519100</td>
#       <td>1.513272</td>
#       <td>0.512476</td>
#       <td>0.262632</td>
#       <td>0.512476</td>
#       <td>0.347287</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>11200</td>
#       <td>1.501000</td>
#       <td>1.516060</td>
#       <td>0.512476</td>
#       <td>0.262632</td>
#       <td>0.512476</td>
#       <td>0.347287</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>11600</td>
#       <td>1.539200</td>
#       <td>1.508581</td>
#       <td>0.512476</td>
#       <td>0.262632</td>
#       <td>0.512476</td>
#       <td>0.347287</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>1.506500</td>
#       <td>1.514146</td>
#       <td>0.512476</td>
#       <td>0.262632</td>
#       <td>0.512476</td>
#       <td>0.347287</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>12400</td>
#       <td>1.533000</td>
#       <td>1.508704</td>
#       <td>0.512476</td>
#       <td>0.262632</td>
#       <td>0.512476</td>
#       <td>0.347287</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>12800</td>
#       <td>1.555800</td>
#       <td>1.510295</td>
#       <td>0.512476</td>
#       <td>0.262632</td>
#       <td>0.512476</td>
#       <td>0.347287</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>13200</td>
#       <td>1.532100</td>
#       <td>1.510476</td>
#       <td>0.512476</td>
#       <td>0.262632</td>
#       <td>0.512476</td>
#       <td>0.347287</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>13600</td>
#       <td>1.538100</td>
#       <td>1.508776</td>
#       <td>0.512476</td>
#       <td>0.262632</td>
#       <td>0.512476</td>
#       <td>0.347287</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>1.532600</td>
#       <td>1.509199</td>
#       <td>0.512476</td>
#       <td>0.262632</td>
#       <td>0.512476</td>
#       <td>0.347287</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>14400</td>
#       <td>1.501800</td>
#       <td>1.509108</td>
#       <td>0.512476</td>
#       <td>0.262632</td>
#       <td>0.512476</td>
#       <td>0.347287</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>14800</td>
#       <td>1.505800<
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-400
# Configuration saved in ./legal_results_eurlex/checkpoint-400/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-800
# Configuration saved in ./legal_results_eurlex/checkpoint-800/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-1200
# Configuration saved in ./legal_results_eurlex/checkpoint-1200/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-1200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-1600
# Configuration saved in ./legal_results_eurlex/checkpoint-1600/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-1600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-2000
# Configuration saved in ./legal_results_eurlex/checkpoint-2000/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-2000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-2400
# Configuration saved in ./legal_results_eurlex/checkpoint-2400/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-2400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-2800
# Configuration saved in ./legal_results_eurlex/checkpoint-2800/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-2800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-3200
# Configuration saved in ./legal_results_eurlex/checkpoint-3200/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-3200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-3600
# Configuration saved in ./legal_results_eurlex/checkpoint-3600/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-3600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-4000
# Configuration saved in ./legal_results_eurlex/checkpoint-4000/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-4000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-4400
# Configuration saved in ./legal_results_eurlex/checkpoint-4400/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-4400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-4800
# Configuration saved in ./legal_results_eurlex/checkpoint-4800/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-4800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-5200
# Configuration saved in ./legal_results_eurlex/checkpoint-5200/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-5200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-5600
# Configuration saved in ./legal_results_eurlex/checkpoint-5600/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-5600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-6000
# Configuration saved in ./legal_results_eurlex/checkpoint-6000/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-6000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-6400
# Configuration saved in ./legal_results_eurlex/checkpoint-6400/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-6400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-6800
# Configuration saved in ./legal_results_eurlex/checkpoint-6800/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-6800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-7200
# Configuration saved in ./legal_results_eurlex/checkpoint-7200/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-7200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-7600
# Configuration saved in ./legal_results_eurlex/checkpoint-7600/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-7600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-8000
# Configuration saved in ./legal_results_eurlex/checkpoint-8000/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-8000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-8400
# Configuration saved in ./legal_results_eurlex/checkpoint-8400/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-8400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-8800
# Configuration saved in ./legal_results_eurlex/checkpoint-8800/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-8800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-9200
# Configuration saved in ./legal_results_eurlex/checkpoint-9200/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-9200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-9600
# Configuration saved in ./legal_results_eurlex/checkpoint-9600/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-9600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-10000
# Configuration saved in ./legal_results_eurlex/checkpoint-10000/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-10000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-10400
# Configuration saved in ./legal_results_eurlex/checkpoint-10400/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-10400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-10800
# Configuration saved in ./legal_results_eurlex/checkpoint-10800/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-10800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-11200
# Configuration saved in ./legal_results_eurlex/checkpoint-11200/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-11200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-11600
# Configuration saved in ./legal_results_eurlex/checkpoint-11600/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-11600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-12000
# Configuration saved in ./legal_results_eurlex/checkpoint-12000/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-12000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-12400
# Configuration saved in ./legal_results_eurlex/checkpoint-12400/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-12400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-12800
# Configuration saved in ./legal_results_eurlex/checkpoint-12800/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-12800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-13200
# Configuration saved in ./legal_results_eurlex/checkpoint-13200/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-13200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-13600
# Configuration saved in ./legal_results_eurlex/checkpoint-13600/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-13600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-14000
# Configuration saved in ./legal_results_eurlex/checkpoint-14000/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-14000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-14400
# Configuration saved in ./legal_results_eurlex/checkpoint-14400/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-14400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-14800
# Configuration saved in ./legal_results_eurlex/checkpoint-14800/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-14800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-15200
# Configuration saved in ./legal_results_eurlex/checkpoint-15200/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-15200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-15600
# Configuration saved in ./legal_results_eurlex/checkpoint-15600/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-15600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-16000
# Configuration saved in ./legal_results_eurlex/checkpoint-16000/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-16000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-16400
# Configuration saved in ./legal_results_eurlex/checkpoint-16400/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-16400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-16800
# Configuration saved in ./legal_results_eurlex/checkpoint-16800/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-16800/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-17200
# Configuration saved in ./legal_results_eurlex/checkpoint-17200/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-17200/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-17600
# Configuration saved in ./legal_results_eurlex/checkpoint-17600/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-17600/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-18000
# Configuration saved in ./legal_results_eurlex/checkpoint-18000/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-18000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-18400
# Configuration saved in ./legal_results_eurlex/checkpoint-18400/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-18400/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ./legal_results_eurlex/checkpoint-18800
# Configuration saved in ./legal_results_eurlex/checkpoint-18800/config.json
# Model weights saved in ./legal_results_eurlex/checkpoint-18800/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./legal_results_eurlex/checkpoint-4400 (score: 1.451322078704834).
# TrainOutput(global_step=18952, training_loss=1.5189283096422974, metrics={'train_runtime': 3258.5814, 'train_samples_per_second': 46.52, 'train_steps_per_second': 5.816, 'total_flos': 2.44615010285892e+16, 'train_loss': 1.5189283096422974, 'epoch': 4.0})

# %%
trainer._load_from_checkpoint("/content/legal_results_eurlex/checkpoint-3600")
# Out:
# Loading model from /content/legal_results_eurlex/checkpoint-3600.

# %%
# evaluate the current model after training
trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 521
#   Batch size = 20
#     <div>
#
#       <progress value='54' max='27' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [27/27 00:49]
#     </div>
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'eval_loss': 1.4527499675750732,
#  'eval_Accuracy': 0.53358925,
#  'eval_Precision': 0.33749874,
#  'eval_Recall': 0.53358925,
#  'eval_F-Score': 0.4039433,
#  'eval_AUC ROC': 0.528023,
#  'eval_runtime': 1.157,
#  'eval_samples_per_second': 450.319,
#  'eval_steps_per_second': 23.337,
#  'epoch': 4.0}

# %%
model1 = BertForSequenceClassification.from_pretrained("/content/legal_results_eurlex/checkpoint-3600", num_labels=len(target_names)).to("cuda")
pred = [get_prediction(i)[1] for i in df_test.Sentence.values.tolist()]
print('Accuracy of Test Dataset :',accuracy_score(pred, df_test.Target.values.tolist()))
# Out:
# loading configuration file /content/legal_results_eurlex/checkpoint-3600/config.json
# Model config BertConfig {
#   "_name_or_path": "nlpaueb/bert-base-uncased-eurlex",
#   "architectures": [
#     "BertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "eos_token_ids": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": null,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "torch_dtype": "float32",
#   "transformers_version": "4.21.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading weights file /content/legal_results_eurlex/checkpoint-3600/pytorch_model.bin
# All model checkpoint weights were used when initializing BertForSequenceClassification.
#
# All the weights of BertForSequenceClassification were initialized from the model checkpoint at /content/legal_results_eurlex/checkpoint-3600.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForSequenceClassification for predictions without further training.
# Accuracy of Test Dataset : 0.5335892514395394

# %%
def confusion_matrixs(y, yp):
  k = sorted(list(set(y)))
  df = pd.DataFrame(index=k, columns=k)
  df.fillna(0, inplace=True)
  for i, j in zip(y, yp):
    df.loc[i, j] += 1
  sns.heatmap(df, annot=True)
  plt.plot()
def multiclass_roc_auc_score(y_test, y_pred, average="macro"):
  lb = LabelBinarizer()
  lb.fit(y_test)
  y_test = lb.transform(y_test)
  y_pred = lb.transform(y_pred)
  return roc_auc_score(y_test, y_pred, average=average)
print(confusion_matrix(df_test.Target.values.tolist(), pred))
precision, recall, fscore, support = precision_recall_fscore_support(df_test.Target.values.tolist(), pred, average='weighted')
print('Accuracy = ',round(accuracy_score(pred, df_test.Target.values.tolist()),8),'\nPrecision = ',round(precision,8),
      '\nRecall = ', round(recall,8), '\nF-Score = ',round(fscore,8), 
      '\nAUC ROC = ', round(multiclass_roc_auc_score(df_test.Target.values.tolist(),np.array(pred), average="macro"),8))
confusion_matrixs(df_test.Target.values.tolist(),np.array(pred))
print(classification_report(df_test.Target.values.tolist(),np.array(pred)))
# Out:
# [[  0   0  76   1   0   0   0]
#  [  0   0  21   5   0   0   0]
#  [  0   0 255  12   0   0   0]
#  [  0   0  42  23   0   0   0]
#  [  0   0  34   0   0   0   0]
#  [  0   0  13   5   0   0   0]
#  [  0   0  34   0   0   0   0]]
# Accuracy =  0.53358925
# Precision =  0.33749874
# Recall =  0.53358925
# F-Score =  0.4039433
# AUC ROC =  0.528023
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        77
#            1       0.00      0.00      0.00        26
#            2       0.54      0.96      0.69       267
#            3       0.50      0.35      0.41        65
#            4       0.00      0.00      0.00        34
#            5       0.00      0.00      0.00        18
#            6       0.00      0.00      0.00        34
#
#     accuracy                           0.53       521
#    macro avg       0.15      0.19      0.16       521
# weighted avg       0.34      0.53      0.40       521
